# %% [markdown]
# <a href="https://colab.research.google.com/github/manaCrypts/my-portfolio/blob/main/work/notebooks/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# Row meaning: One row = one search query impression from Google Search Console for my lane.
#
# Tables used: search_console_queries (joined with analytics_sessions if needed).
#
# Time window: Mid‑panel month 2026‑03.
#
# Predict or rank: Predict likelihood of a click (CTR proxy).
#
# Deliberate exclusion: Exclude branded queries (company name terms).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# Feature frame for March 2026:
#
# Impressions — knowable at decision moment because daily sync logs impressions.
#
# Clicks — knowable because Search Console reports clicks daily.
#
# CTR (clicks/impressions) — computable instantly from logged values.
#
# Query length — knowable from the query text string itself.
#
# Average position — knowable because Google reports position daily.

# %% [markdown]
# The Trap (Leakage)
# Added column: future_clicks_next_week (label‑derived).
#
# Quick model score jumped to ~0.95 AUC (unrealistically high).
#
# Removed column → honest score dropped to ~0.68 AUC.
#
# Lesson: leakage occurred because the feature was derived from the label; removing it restored honest performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# | query | date | clicks | impressions |
# | --- | --- | --- | --- |
# | "cyber tools" | 2026-03-01 | 3 | 120 |
# | "ai project" | 2026-03-01 | 5 | 200 |
#
# | row_count | start_date | end_date |
# | --- | --- | --- |
# | 1,245,322 | 2026-03-01 | 2026-03-31 |
#
# | available_rows |
# | --- |
# | 1,240,876 |

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

-- Grain check: one row really is one query impression
SELECT query, date, clicks, impressions
FROM search_console_queries
WHERE month = '2026-03'
LIMIT 5;
-- Row count and date span
SELECT COUNT(*) AS row_count,
       MIN(date) AS start_date,
       MAX(date) AS end_date
FROM search_console_queries
WHERE month = '2026-03';
-- Availability check with IS TRUE
SELECT COUNT(*) AS available_rows
FROM search_console_queries
WHERE month = '2026-03'
  AND impressions IS TRUE;

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# Limitation: This slice excludes queries with zero impressions, so silent failures (queries never shown to users) aren’t modeled.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [* ] Every section above is filled — markdown thinking AND the code that backs it
# - [ *] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ *] No client names, URLs, or private queries anywhere
# - [ *] My claims use careful words: observed, measured, directional, decision-support
# - [ *] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
