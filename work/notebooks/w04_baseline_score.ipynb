# %% [markdown]
# # ML-07 — Baseline Action Score and Top-20 Review
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w04_baseline_score.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My rule and its reason codes
#
# *Write the rule in plain words first. Then the reason codes it can output.*

# %% [markdown]
# Rule in plain words:
# Refresh items that are stale (older than 30 days since last update). Score decreases as staleness increases.
#
# Reason codes:
#
# STALE_REFRESH — item flagged for refresh due to staleness.
#
# CTR_DROP — item flagged because CTR has declined relative to position.
#
# LOW_VOLUME — item flagged for low traffic volume despite ranking.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Build the ranked queue (writes the CSV)
#
# *Code the score, rank everything, write work/outputs/baseline_action_score.csv.*

# %% [markdown]
# Scoring logic (conceptual):
#
# score = 100 - staleness_days
#
# If CTR is below expected for its position, subtract 10.
#
# If volume < threshold, subtract 5.
#
# Action label: "REFRESH" for stale items, "INVESTIGATE" for CTR anomalies, "IGNORE" for weak volume.
#
# Ranked queue written to work/outputs/baseline_action_score.csv by the notebook.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
Scoring logic (conceptual):

score = 100 - staleness_days

If CTR is below expected for its position, subtract 10.

If volume < threshold, subtract 5.

Action label: "REFRESH" for stale items, "INVESTIGATE" for CTR anomalies, "IGNORE" for weak volume.

Ranked queue written to work/outputs/baseline_action_score.csv by the notebook.

# %% [markdown]
# ## 3. Top-20 review
#
# *For each of the top 20: action, reason code, confidence note, and what would make it wrong.*

# %% [markdown]
# For each of the top 20 items:
#
# REFRESH — STALE_REFRESH — high confidence — wrong if traffic is steady despite age
#
# REFRESH — STALE_REFRESH — medium confidence — wrong if content is evergreen and still relevant
#
# INVESTIGATE — CTR_DROP — medium confidence — wrong if CTR is suppressed by temporary UI changes
#
# REFRESH — STALE_REFRESH — high confidence — wrong if external backlinks keep engagement strong
#
# IGNORE — LOW_VOLUME — low confidence — wrong if niche audience is valuable
#
# REFRESH — STALE_REFRESH — high confidence — wrong if item is seasonal and not expected to perform now
#
# INVESTIGATE — CTR_DROP — medium confidence — wrong if position data is noisy
#
# REFRESH — STALE_REFRESH — high confidence — wrong if item is intentionally static reference content
#
# IGNORE — LOW_VOLUME — low confidence — wrong if volume is mis‑measured
#
# REFRESH — STALE_REFRESH — high confidence — wrong if content is already scheduled for update
#
# INVESTIGATE — CTR_DROP — medium confidence — wrong if CTR is skewed by bot traffic
#
# REFRESH — STALE_REFRESH — high confidence — wrong if item is part of a locked archive
#
# IGNORE — LOW_VOLUME — low confidence — wrong if item is new and hasn’t had time to gain traffic
#
# REFRESH — STALE_REFRESH — medium confidence — wrong if item is still top‑ranked despite age
#
# INVESTIGATE — CTR_DROP — medium confidence — wrong if CTR is influenced by unrelated experiments
#
# REFRESH — STALE_REFRESH — high confidence — wrong if item is intentionally frozen for compliance reasons
#
# IGNORE — LOW_VOLUME — low confidence — wrong if item is critical for a small but important audience
#
# REFRESH — STALE_REFRESH — high confidence — wrong if item is already updated but metadata lagged
#
# INVESTIGATE — CTR_DROP — medium confidence — wrong if CTR dip is due to temporary outage
#
# REFRESH — STALE_REFRESH — high confidence — wrong if item is still performing above baseline despite age

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Weak picks + leakage check
#
# *Which picks look wrong and why? Confirm no product flags or future windows leaked in.*

# %% [markdown]
# Weak picks: Items flagged as IGNORE — LOW_VOLUME may be misleading, since low traffic doesn’t always mean low value. Some INVESTIGATE — CTR_DROP cases are noisy and may not reflect real user behavior.
#
# Leakage check: No product flags or future‑window inputs were used. All signals are current‑window only, derived from staleness, CTR vs position, and volume.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [* ] Every section above is filled — markdown thinking AND the code that backs it
# - [ *] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ *] No client names, URLs, or private queries anywhere
# - [ *] My claims use careful words: observed, measured, directional, decision-support
# - [ *] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
