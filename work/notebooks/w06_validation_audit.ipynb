# %% [markdown]
# <a href="https://colab.research.google.com/github/manaCrypts/my-portfolio/blob/main/work/notebooks/w06_validation_audit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w06_validation_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*

# %% [markdown]
# ### Paper Finding 1
# Claim: "Our model achieved 92% accuracy on client classification."
#
# **Methodology Question:**
# Where do the labels for client classification originate? Are they human-verified, or derived from automated logs? If automated, what safeguards ensure correctness?
#
# ---
#
# ### Paper Finding 2
# Claim: "Temporal validation shows stable performance across months."
#
# **Methodology Question:**
# Was the validation design time-aware enough to prevent leakage (e.g., training on later months and testing on earlier ones)? How were seasonal or client onboarding effects accounted for?

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*

# %% [markdown]
# ### Before: Random Split
# - Accuracy: 0.89
# - F1 Score: 0.87
# - Observed issue: Same client appears in both train and test, inflating performance.
#
# ### After: Grouped by Client Split
# - Accuracy: 0.74
# - F1 Score: 0.71
# - Observed: Drop in performance, but more honest reflection of generalization to unseen clients.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*

# %% [markdown]
# ### Leakage Audit
# - Feature: `client_id` → Direct leakage, removed.
# - Feature: `signup_date` → Time-aware, but must ensure train/test split respects chronology.
# - Feature: `last_transaction_amount` → Safe, but correlated with target; flagged for monitoring.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*

# %% [markdown]
# ### Original Claim
# "Our model predicts client churn with 90% accuracy."
#
# ### Revised Claim
# "Our model achieved 74% accuracy under a grouped split. This suggests directional decision-support for churn risk, but performance varies by client and time period."

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ *] Every section above is filled — markdown thinking AND the code that backs it
# - [ *] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ *] No client names, URLs, or private queries anywhere
# - [ *] My claims use careful words: observed, measured, directional, decision-support
# - [ *] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
